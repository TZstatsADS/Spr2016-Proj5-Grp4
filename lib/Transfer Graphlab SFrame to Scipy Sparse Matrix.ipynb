# %%
import graphlab as gl
import pandas as pd

# %%
train_imgs = gl.SFrame('../output/train_imgs_unpack.csv')
# Out:
# Finished parsing file /Users/voelunteer/Project/Kaggle/StateFarm/output/train_imgs_unpack.csv
# Parsing completed. Parsed 100 lines in 1.6984 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# ...

# %%
train_imgs.head()
# Out:
# Columns:
# 	path	str
# 	image	str
# 	label	str
# 	img_name	str
# 	deep_features.0	float
# 	deep_features.1	float
# 	deep_features.2	float
# 	deep_features.3	float
# 	deep_features.4	float
# 	deep_features.5	float
# 	deep_features.6	int
# 	deep_features.7	float
# 	deep_features.8	float
# 	deep_features.9	float
# 	deep_features.10	float
# 	deep_features.11	float
# 	deep_features.12	int
# 	deep_features.13	float
# 	deep_features.14	float
# 	deep_features.15	float
# 	deep_features.16	float
# 	deep_features.17	float
# 	deep_features.18	float
# 	deep_features.19	float
# 	deep_features.20	int
# 	deep_features.21	float
# 	deep_features.22	float
# 	deep_features.23	float
# 	deep_features.24	float
# 	deep_features.25	float
# 	deep_features.26	float
# 	deep_features.27	float
# 	deep_features.28	float
# 	deep_features.29	float
# 	deep_features.30	float
# 	deep_features.31	int
# 	deep_features.32	float
# 	deep_features.33	float
# 	deep_features.34	float
# 	deep_features.35	float
# ...

# %%
train_imgs = train_imgs.remove_columns(['path', 'image'])

# %%
train = train_imgs.to_dataframe()

# %%
sparse_train = train.to_sparse()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4d151d13942c> in <module>()
# ----> 1 sparse_train = train.to_sparse()
#
# /Users/voelunteer/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in to_sparse(self, fill_value, kind)
#    1204         return SparseDataFrame(self._series, index=self.index,
#    1205                                columns=self.columns, default_kind=kind,
# -> 1206                                default_fill_value=fill_value)
#    1207
#    1208     def to_panel(self):
#
# /Users/voelunteer/anaconda/lib/python2.7/site-packages/pandas/sparse/frame.pyc in __init__(self, data, index, columns, default_kind, default_fill_value, dtype, copy)
#      78
#      79         if isinstance(data, dict):
# ---> 80             mgr = self._init_dict(data, index, columns)
#      81             if dtype is not None:
# ...

# %%
sparse_train
